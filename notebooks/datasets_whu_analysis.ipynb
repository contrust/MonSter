# %%
import os
import PIL.Image as Image
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from collections import Counter
import pandas as pd
from enum import Enum

DATASET_PATH = "../datasets/whu"
GROUND_TRUTH_PATH = os.path.join(DATASET_PATH, "with ground truth")
TRAIN_PATH = os.path.join(GROUND_TRUTH_PATH, "train")
VAL_PATH = os.path.join(GROUND_TRUTH_PATH, "val")
TEST_PATH = os.path.join(GROUND_TRUTH_PATH, "test")

TRAIN_DISPARITY_PATH = os.path.join(TRAIN_PATH, "disp")
VAL_DISPARITY_PATH = os.path.join(VAL_PATH, "disp")
TEST_DISPARITY_PATH = os.path.join(TEST_PATH, "disp")

VAL_LEFT_IMAGES_PATHS = [os.path.join(VAL_PATH, "left", f) for f in os.listdir(os.path.join(VAL_PATH, "left"))]
VAL_RIGHT_IMAGES_PATHS = [os.path.join(VAL_PATH, "right", f) for f in os.listdir(os.path.join(VAL_PATH, "right"))]
VAL_DISPARITY_IMAGES_PATHS = [os.path.join(VAL_PATH, "disp", f) for f in os.listdir(os.path.join(VAL_PATH, "disp"))]

VAL_LEFT_IMAGES_PATHS.sort()
VAL_RIGHT_IMAGES_PATHS.sort()
VAL_DISPARITY_IMAGES_PATHS.sort()


def load_image(path) -> np.ndarray:
    image = np.array(Image.open(path)).astype(np.int16)
    return image

INVALID_DISPARITY_VALUE = -999

invalid_disp_count = 0

disp_dist = Counter()

for image_path in tqdm(VAL_DISPARITY_IMAGES_PATHS):
    image = load_image(image_path)
    disp_dist.update(image.flatten())

disp_dist_df = pd.DataFrame(disp_dist.items(), columns=["disp", "count"])
disp_dist_df.sort_values(by="count", inplace=True, ascending=False)
disp_dist_df.reset_index(drop=True, inplace=True)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
disp_dist_df.style.hide(axis="index")

disp_dist_df
# Out:
#                  left              right                   disp
# 0    KM_left_226.tiff  KM_right_226.tiff  KM_disparity_226.tiff
# 1    KM_left_251.tiff  KM_right_251.tiff  KM_disparity_251.tiff
# 2    KM_left_253.tiff  KM_right_253.tiff  KM_disparity_253.tiff
# 3    QC_left_110.tiff  QC_right_110.tiff  QC_disparity_110.tiff
# 4    QC_left_147.tiff  QC_right_147.tiff  QC_disparity_147.tiff
# 5    QC_left_150.tiff  QC_right_150.tiff  QC_disparity_150.tiff
# 6    QC_left_166.tiff  QC_right_166.tiff  QC_disparity_166.tiff
# 7    QC_left_175.tiff  QC_right_175.tiff  QC_disparity_175.tiff
# 8    QC_left_182.tiff  QC_right_182.tiff  QC_disparity_182.tiff
# 9    QC_left_187.tiff  QC_right_187.tiff  QC_disparity_187.tiff
# 10    QC_left_19.tiff   QC_right_19.tiff   QC_disparity_19.tiff
# 11   QC_left_192.tiff  QC_right_192.tiff  QC_disparity_192.tiff
# 12   QC_left_197.tiff  QC_right_197.tiff  QC_disparity_197.tiff
# 13   QC_left_198.tiff  QC_right_198.tiff  QC_disparity_198.tiff
# 14   QC_left_207.tiff  QC_right_207.tiff  QC_disparity_207.tiff
# 15   QC_left_217.tiff  QC_right_217.tiff  QC_disparity_217.tiff
# 16   QC_left_241.tiff  QC_right_241.tiff  QC_disparity_241.tiff
# 17    QC_left_26.tiff   QC_right_26.tiff   QC_disparity_26.tiff
# 18   QC_left_265.tiff  QC_right_265.tiff  QC_disparity_265.tiff
# 19   QC_left_278.tiff  QC_right_278.tiff  QC_disparity_278.tiff
# 20   QC_left_285.tiff  QC_right_285.tiff  QC_disparity_285.tiff
# 21   QC_left_291.tiff  QC_right_291.tiff  QC_disparity_291.tiff
# 22    QC_left_34.tiff   QC_right_34.tiff   QC_disparity_34.tiff
# 23   QC_left_372.tiff  QC_right_372.tiff  QC_disparity_372.tiff
# 24   QC_left_394.tiff  QC_right_394.tiff  QC_disparity_394.tiff
# 25   QC_left_403.tiff  QC_right_403.tiff  QC_disparity_403.tiff
# 26   QC_left_411.tiff  QC_right_411.tiff  QC_disparity_411.tiff
# 27   QC_left_414.tiff  QC_right_414.tiff  QC_disparity_414.tiff
# 28   QC_left_442.tiff  QC_right_442.tiff  QC_disparity_442.tiff
# 29   QC_left_464.tiff  QC_right_464.tiff  QC_disparity_464.tiff
# 30   QC_left_475.tiff  QC_right_475.tiff  QC_disparity_475.tiff
# 31    QC_left_49.tiff   QC_right_49.tiff   QC_disparity_49.tiff
# 32   QC_left_512.tiff  QC_right_512.tiff  QC_disparity_512.tiff
# 33   QC_left_524.tiff  QC_right_524.tiff  QC_disparity_524.tiff
# 34   QC_left_535.tiff  QC_right_535.tiff  QC_disparity_535.tiff
# 35   QC_left_538.tiff  QC_right_538.tiff  QC_disparity_538.tiff
# 36   QC_left_556.tiff  QC_right_556.tiff  QC_disparity_556.tiff
# 37   QC_left_562.tiff  QC_right_562.tiff  QC_disparity_562.tiff
# 38   QC_left_564.tiff  QC_right_564.tiff  QC_disparity_564.tiff
# 39    QC_left_59.tiff   QC_right_59.tiff   QC_disparity_59.tiff
# 40   QC_left_608.tiff  QC_right_608.tiff  QC_disparity_608.tiff
# 41   QC_left_615.tiff  QC_right_615.tiff  QC_disparity_615.tiff
# 42   QC_left_622.tiff  QC_right_622.tiff  QC_disparity_622.tiff
# 43   QC_left_655.tiff  QC_right_655.tiff  QC_disparity_655.tiff
# 44    QC_left_67.tiff   QC_right_67.tiff   QC_disparity_67.tiff
# 45   QC_left_674.tiff  QC_right_674.tiff  QC_disparity_674.tiff
# 46   QC_left_690.tiff  QC_right_690.tiff  QC_disparity_690.tiff
# 47   QC_left_692.tiff  QC_right_692.tiff  QC_disparity_692.tiff
# 48   QC_left_693.tiff  QC_right_693.tiff  QC_disparity_693.tiff
# 49   QC_left_704.tiff  QC_right_704.tiff  QC_disparity_704.tiff
# 50   QC_left_715.tiff  QC_right_715.tiff  QC_disparity_715.tiff
# 51   QC_left_716.tiff  QC_right_716.tiff  QC_disparity_716.tiff
# 52   QC_left_728.tiff  QC_right_728.tiff  QC_disparity_728.tiff
# 53   QC_left_736.tiff  QC_right_736.tiff  QC_disparity_736.tiff
# 54    QC_left_74.tiff   QC_right_74.tiff   QC_disparity_74.tiff
# 55   QC_left_752.tiff  QC_right_752.tiff  QC_disparity_752.tiff
# 56   QC_left_753.tiff  QC_right_753.tiff  QC_disparity_753.tiff
# 57   QC_left_779.tiff  QC_right_779.tiff  QC_disparity_779.tiff
# 58   QC_left_790.tiff  QC_right_790.tiff  QC_disparity_790.tiff
# 59   QC_left_791.tiff  QC_right_791.tiff  QC_disparity_791.tiff
# 60     QC_left_8.tiff    QC_right_8.tiff    QC_disparity_8.tiff
# 61   QC_left_820.tiff  QC_right_820.tiff  QC_disparity_820.tiff
# 62   QC_left_829.tiff  QC_right_829.tiff  QC_disparity_829.tiff
# 63   QC_left_831.tiff  QC_right_831.tiff  QC_disparity_831.tiff
# 64    QC_left_84.tiff   QC_right_84.tiff   QC_disparity_84.tiff
# 65   QC_left_847.tiff  QC_right_847.tiff  QC_disparity_847.tiff
# 66   QC_left_866.tiff  QC_right_866.tiff  QC_disparity_866.tiff
# 67    QC_left_88.tiff   QC_right_88.tiff   QC_disparity_88.tiff
# 68   QC_left_901.tiff  QC_right_901.tiff  QC_disparity_901.tiff
# 69   QC_left_902.tiff  QC_right_902.tiff  QC_disparity_902.tiff
# 70   QC_left_906.tiff  QC_right_906.tiff  QC_disparity_906.tiff
# 71   QC_left_911.tiff  QC_right_911.tiff  QC_disparity_911.tiff
# 72   QC_left_916.tiff  QC_right_916.tiff  QC_disparity_916.tiff
# 73   QC_left_919.tiff  QC_right_919.tiff  QC_disparity_919.tiff
# 74   QC_left_920.tiff  QC_right_920.tiff  QC_disparity_920.tiff
# 75   QC_left_921.tiff  QC_right_921.tiff  QC_disparity_921.tiff
# 76   QC_left_923.tiff  QC_right_923.tiff  QC_disparity_923.tiff
# 77   QC_left_924.tiff  QC_right_924.tiff  QC_disparity_924.tiff
# 78   QC_left_926.tiff  QC_right_926.tiff  QC_disparity_926.tiff
# 79   QC_left_927.tiff  QC_right_927.tiff  QC_disparity_927.tiff
# 80   QC_left_931.tiff  QC_right_931.tiff  QC_disparity_931.tiff
# 81   QC_left_963.tiff  QC_right_963.tiff  QC_disparity_963.tiff
# 82   QC_left_996.tiff  QC_right_996.tiff  QC_disparity_996.tiff
# 83    SG_left_67.tiff   SG_right_67.tiff   SG_disparity_67.tiff
# 84    SG_left_68.tiff   SG_right_68.tiff   SG_disparity_68.tiff
# 85    SG_left_69.tiff   SG_right_69.tiff   SG_disparity_69.tiff
# 86    SG_left_73.tiff   SG_right_73.tiff   SG_disparity_73.tiff
# 87    SG_left_74.tiff   SG_right_74.tiff   SG_disparity_74.tiff
# 88   YD_left_105.tiff  YD_right_105.tiff  YD_disparity_105.tiff
# 89   YD_left_112.tiff  YD_right_112.tiff  YD_disparity_112.tiff
# 90   YD_left_125.tiff  YD_right_125.tiff  YD_disparity_125.tiff
# 91   YD_left_143.tiff  YD_right_143.tiff  YD_disparity_143.tiff
# 92   YD_left_144.tiff  YD_right_144.tiff  YD_disparity_144.tiff
# 93   YD_left_177.tiff  YD_right_177.tiff  YD_disparity_177.tiff
# 94   YD_left_184.tiff  YD_right_184.tiff  YD_disparity_184.tiff
# 95   YD_left_212.tiff  YD_right_212.tiff  YD_disparity_212.tiff
# 96   YD_left_219.tiff  YD_right_219.tiff  YD_disparity_219.tiff
# 97   YD_left_229.tiff  YD_right_229.tiff  YD_disparity_229.tiff
# 98   YD_left_327.tiff  YD_right_327.tiff  YD_disparity_327.tiff
# 99    YD_left_34.tiff   YD_right_34.tiff   YD_disparity_34.tiff
# 100  YD_left_347.tiff  YD_right_347.tiff  YD_disparity_347.tiff
# 101  YD_left_352.tiff  YD_right_352.tiff  YD_disparity_352.tiff
# 102  YD_left_354.tiff  YD_right_354.tiff  YD_disparity_354.tiff
# 103  YD_left_360.tiff  YD_right_360.tiff  YD_disparity_360.tiff
# 104  YD_left_371.tiff  YD_right_371.tiff  YD_disparity_371.tiff
# 105  YD_left_391.tiff  YD_right_391.tiff  YD_disparity_391.tiff
# 106  YD_left_404.tiff  YD_right_404.tiff  YD_disparity_404.tiff
# 107  YD_left_422.tiff  YD_right_422.tiff  YD_disparity_422.tiff
# 108  YD_left_437.tiff  YD_right_437.tiff  YD_disparity_437.tiff
# 109  YD_left_467.tiff  YD_right_467.tiff  YD_disparity_467.tiff
# 110  YD_left_483.tiff  YD_right_483.tiff  YD_disparity_483.tiff
# 111  YD_left_493.tiff  YD_right_493.tiff  YD_disparity_493.tiff
# 112  YD_left_498.tiff  YD_right_498.tiff  YD_disparity_498.tiff
# 113   YD_left_54.tiff   YD_right_54.tiff   YD_disparity_54.tiff
# 114  YD_left_547.tiff  YD_right_547.tiff  YD_disparity_547.tiff
# 115   YD_left_55.tiff   YD_right_55.tiff   YD_disparity_55.tiff
# 116  YD_left_556.tiff  YD_right_556.tiff  YD_disparity_556.tiff
# 117  YD_left_560.tiff  YD_right_560.tiff  YD_disparity_560.tiff
# 118  YD_left_561.tiff  YD_right_561.tiff  YD_disparity_561.tiff
# 119  YD_left_597.tiff  YD_right_597.tiff  YD_disparity_597.tiff
# 120  YD_left_606.tiff  YD_right_606.tiff  YD_disparity_606.tiff
# 121   YD_left_95.tiff   YD_right_95.tiff   YD_disparity_95.tiff
